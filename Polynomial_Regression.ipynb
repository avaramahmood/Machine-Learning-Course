# %% [markdown]
# <a href="https://colab.research.google.com/github/avaramahmood/Machine-Learning-Course/blob/main/Polynomial_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Integrating Data file from Github

# %%
# !git clone https://github.com/avaramahmood/Machine-Learning-Course.git
# %cd Machine-Learning-Course/Regression/Polynomial-Regression
# Out:
# Cloning into 'Machine-Learning-Course'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 68 (delta 18), reused 4 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (68/68), 71.41 KiB | 1.40 MiB/s, done.
# Resolving deltas: 100% (18/18), done.
# /content/Machine-Learning-Course/Regression/Polynomial-Regression/Machine-Learning-Course/Regression/Polynomial-Regression/Machine-Learning-Course/Regression/Polynomial-Regression/Machine-Learning-Course/Regression/Polynomial-Regression/Machine-Learning-Course/Regression/Polynomial-Regression/Machine-Learning-Course/Regression/Polynomial-Regression/Machine-Learning-Course/Regression/Polynomial-Regression

# %% [markdown]
# ## Importing Dataset and libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('Position_Salaries.csv')
X = df.iloc[:, 1:-1].values
y = df.iloc[:, -1].values

# %% [markdown]
# ## Implementing the Linear Regression Model on the Dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Implementing Polynomial Regression on the Dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 4)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predicting the values with Linear Regression Model

# %%
y_lin_pred = lin_reg.predict(X.reshape(-1, 1))

# %% [markdown]
# ## Predicting values of Poly Regression

# %%
y_poly_pred = lin_reg_2.predict(X_poly)

# %% [markdown]
# ## Plotting Linear Regression Model

# %%
plt.scatter(X,y, color = 'red')
plt.plot(X,y_lin_pred, color = 'blue')
plt.title('Linear Regression Model')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# Plotting Poly Regression Model

# %%
plt.scatter(X,y, color = 'red')
plt.plot(X,y_poly_pred, color = 'blue')
plt.title('Linear Regression Model')
plt.xlabel('Position Level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ##Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.plot(X_grid, lin_reg_2.predict(poly_reg.fit_transform(X_grid)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
# Out:
# <ipython-input-48-72d1221b8e2e>:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)

# %% [markdown]
# Predicting a new Result with Linear Regression

# %%
print(lin_reg.predict([[8]]))
# Out:
# [451696.96969697]

# %% [markdown]
# Predicting a new Result with Poly Regression

# %%
print(lin_reg_2.predict(poly_reg.fit_transform([[8]])))
# Out:
# [289994.17249417]
